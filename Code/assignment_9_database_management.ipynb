# %% [markdown]
# <a href="https://colab.research.google.com/github/smlicciardello-svg/MPM_200_Licciardello/blob/main/Code/assignment_9_database_management.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Python Packages and Scientific Computing Libraries
#
# """
# Python Packages Overview:
# -------------------------
# Packages in Python are collections of modules that provide reusable code and functionality.
# They allow developers to organize and share complex code libraries that can be easily imported
# and used across different projects.
#
# Key Characteristics of Packages:
# - Organized hierarchically
# - Contain multiple related modules
# - Can be installed using package managers like pip
# - Extend Python's core functionality
#
# Three Essential Data Science Libraries:
# --------------------------------------
# 1. Pandas (pd):
#    - Primary library for data manipulation and analysis
#    - Provides DataFrame: a 2D labeled data structure with columns of potentially different types
#    - Key Features:
#      * Reading/writing data from various sources (CSV, Excel, SQL databases)
#      * Data cleaning and preprocessing
#      * Complex data transformations
#      * Powerful data analysis and aggregation tools
#
# 2. NumPy (np):
#    - Fundamental package for scientific computing in Python
#    - Introduces the ndarray (n-dimensional array) for efficient numerical operations
#    - Key Features:
#      * High-performance multidimensional array object
#      * Mathematical and statistical functions
#      * Linear algebra operations
#      * Foundation for scientific and numerical computing
#      * Enables fast computations on large datasets
#
# 3. Matplotlib (plt):
#    - Comprehensive library for creating static, animated, and interactive visualizations
#    - Provides MATLAB-like plotting interface
#    - Key Features:
#      * Line plots, scatter plots, bar charts, histograms
#      * Customizable plot styles and layouts
#      * Support for multiple plot types and graph formats
#      * Integration with NumPy for data visualization
#
# Practical Significance:
# ----------------------
# These libraries form the backbone of data science and scientific computing in Python,
# enabling complex data analysis, numerical computations, and insightful visualizations
# with minimal code.
# """

# %%
# Import required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Read the Excel file
df = pd.read_excel("/content/Flavivirus host associations.xlsx")

# Display basic information about the dataset
print(df.info())

# Show the first few rows of the data
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 570 entries, 0 to 569
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   sr no.                  570 non-null    int64
#  1   Virus                   570 non-null    object
#  2   Scientific Name         570 non-null    object
#  3   Authors                 570 non-null    object
#  4   Year                    430 non-null    object
#  5   Title/accession number  570 non-null    object
#  6   Journal                 425 non-null    object
#  7   Issue                   415 non-null    float64
#  8   Volume                  404 non-null    object
#  9   Pages                   404 non-null    object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 44.7+ KB
# None
#    sr no.         Virus     Scientific Name  \
# 0       3    Apoi virus       Rattus rattus
# 1       2    Apoi virus    Myodes rufocanus
# 2       0    Apoi virus  Apodemus argenteus
# 3       1    Apoi virus  Apodemus speciosus
# 4       4  Bagaza virus      Alectoris rufa
#
#                                              Authors  Year  \
# 0  C. M. Baak-Baak, N. Cigarroa-Toledo, O. M. Tor...  2016
# 1                                        CDC Arbocat   NaN
# 2                 J. S. Mackenzie and D. T. Williams  2009
# 3                 J. S. Mackenzie and D. T. Williams  2009
# 4  D. Buitrago, A. Rocha, C. Tena-Tomas, M. Vigo,...  2012
#
#                               Title/accession number  \
# 0  New Records of Ectoparasites Echinolaelaps ech...
# 1                                        CDC Arbocat
# 2  The zoonotic flaviviruses of southern, south-e...
# 3  The zoonotic flaviviruses of southern, south-e...
# 4  Real-time fluorogenic reverse transcription po...
#
#                      Journal  Issue Volume   Pages
# 0  Southwestern Entomologist    NaN    NaN     NaN
# 1                        NaN    NaN    NaN     NaN
# 2     Zoonoses Public Health   56.0    6-7  338-56
# 3     Zoonoses Public Health   56.0    6-7  338-56
# 4         J Vet Diagn Invest   24.0      5  959-63

# %% [markdown]
# ## Using pandas functions that you have seen in the class address following questions
# 1. How many entries are there in the dataset?
# 2. How many viruses are present in the dataset?
# 3. List those viruses.
# 4. How many rows of data are present for each virus?
# 5. How many host species are present in the data?
# 6. Make a list of host species present.
# 7. Count the number of unique host species for each virus.
# 8. Which virus has the most number of hosts?
# 9. Which host has most number of viruses?

# %%
# Count total number of entries in the dataset- 570 entries
df.shape
# Out:
# (570, 10)

# %%
# Count unique viruses- 30
df.Virus.nunique()
# Out:
# 30

# %%
# List of unique viruses
df.Virus.unique().tolist()
# Out:
# ['Apoi virus',
#  'Bagaza virus',
#  'Banzi virus',
#  'Bouboui virus',
#  'Bussuquara virus',
#  'Cacipacore virus',
#  'Dakar bat virus',
#  'Dengue virus',
#  'Entebbe bat virus',
#  'Iguape virus',
#  'Ilheus virus',
#  'Japanese encephalitis virus',
#  'Koutango virus',
#  'Kunjin virus',
#  'Kyasanur forest virus',
#  'Louping-ill virus',
#  'Modoc virus',
#  'Murray Valley encephalitis virus',
#  'Omsk hemorrhagic fever virus',
#  'Rio Bravo virus',
#  'Rocio virus',
#  'St. Louis Encephalitis virus',
#  'Tembusu virus',
#  'Tickborne encephalitis virus',
#  'Uganda S virus',
#  'Usutu virus',
#  'Wesselsbron virus',
#  'West Nile virus',
#  'Yellow fever virus',
#  'Zika virus']

# %%
# Count of each unique virus
df.groupby('Virus').agg({'sr no.' : 'count'})
# Out:
#                                   sr no.
# Virus
# Apoi virus                             4
# Bagaza virus                           2
# Banzi virus                            2
# Bouboui virus                          1
# Bussuquara virus                       3
# Cacipacore virus                       1
# Dakar bat virus                        5
# Dengue virus                          27
# Entebbe bat virus                      6
# Iguape virus                           1
# Ilheus virus                           5
# Japanese encephalitis virus           25
# Koutango virus                         1
# Kunjin virus                           3
# Kyasanur forest virus                  6
# Louping-ill virus                     13
# Modoc virus                            3
# Murray Valley encephalitis virus       3
# Omsk hemorrhagic fever virus           3
# Rio Bravo virus                        9
# Rocio virus                            2
# St. Louis Encephalitis virus          72
# Tembusu virus                          2
# Tickborne encephalitis virus          84
# Uganda S virus                         7
# Usutu virus                           65
# Wesselsbron virus                      3
# West Nile virus                      194
# Yellow fever virus                    11
# Zika virus                             7

# %%
# Count unique host species
df['Scientific Name'].nunique()
# Out:
# 419

# %%
# List of unique host species
df['Scientific Name'].unique().tolist()
# Out:
# ['Rattus rattus',
#  'Myodes rufocanus',
#  'Apodemus argenteus',
#  'Apodemus speciosus',
#  'Alectoris rufa',
#  'Phasianus colchicus',
#  'Mastomys natalensis',
#  'Mesocricetus auratus',
#  'Papio papio',
#  'Equus caballus',
#  'Alouatta belzebul',
#  'Proechimys guyannensis',
#  'Chaerephon pumilus',
#  'Taphozous perforatus',
#  'Mops condylurus',
#  'Scotophilus nigrita',
#  'Otomops sp',
#  'Carollia brevicauda',
#  'Molossus molossus',
#  'Myotis nigricans',
#  'Natalus stramineus',
#  'Rousettus leschenaultii',
#  'Artibeus planirostris',
#  'Caluromys philander',
#  'Carollia perspicillata',
#  'Didelphis marsupialis',
#  'Hylaeamys megacephalus',
#  'Marmosa demerarae',
#  'Marmosa murina',
#  'Marmosops parvidens',
#  'Mesomys hispidus',
#  'Oecomys sp',
#  'Philander opossum',
#  'Proechimys cuvieri',
#  'Zygodontomys brevicauda',
#  'Artibeus jamaicensis',
#  'Artibeus lituratus',
#  'Glossophaga soricina',
#  'Artibeus sp',
#  'Uroderma sp',
#  'Macaca nemestrina',
#  'Mus musculus',
#  'Eidolon helvum',
#  'Pipistrellus pipistrellus',
#  'Rhinolophus sp',
#  'Rousettus spinalatus',
#  'Macaca mulatta',
#  'Equus ferus',
#  'Molothrus bonariensis',
#  'Sporophila caerulescens',
#  'Hipposideros armiger',
#  'Rhinolophus pusillus',
#  'Vespertilio sinensis',
#  'Bos taurus',
#  'Bos gaurus',
#  'Crocidura macowi',
#  'Turdus merula',
#  'Turdus iliacus',
#  'Sturnus vulgaris',
#  'Turdus philomelos',
#  'Columba livia',
#  'Sus scrofa',
#  'Alouatta pigra',
#  'Sus domesticus',
#  'Myotis pilosus',
#  'Scotophilus kuhlii',
#  'Rhinolophus affinis',
#  'Miniopterus schreibersii',
#  'Ovis aries',
#  'Murina aurata',
#  'Padda oryzivora',
#  'Spilopelia chinensis',
#  'Gallus gallus',
#  'Oriolus flavocinctus',
#  'Pteropus sp',
#  'Vandeleuria oleracea',
#  'Macaca radiata',
#  'Madromys blanfordi',
#  'Semnopithecus entellus',
#  'Capra aegagrus',
#  'Capra hircus',
#  'Apodemus sylvaticus',
#  'Canis lupus',
#  'Capreolus capreolus',
#  'Cervus elaphus',
#  'Lagopus lagopus',
#  'Lepus timidus',
#  'Sorex araneus',
#  'Peromyscus maniculatus',
#  'Egretta novaehollandiae',
#  'Microtus gregalis',
#  'Ondatra zibethicus',
#  'Microtus oeconomus',
#  'Molossus rufus',
#  'Tadarida brasiliensis',
#  'Eptesicus fuscus',
#  'Desmodus rotundus',
#  'Sturnira lilium',
#  'Zonotrichia capensis',
#  'Agelaioides badius',
#  'Agelaius phoeniceus',
#  'Alouatta sp',
#  'Ateles paniscus',
#  'Bradypus variegatus',
#  'Bubo virginianus',
#  'Buteogallus coronatus',
#  'Butorides striata',
#  'Callipepla gambelii',
#  'Calomys musculinus',
#  'Campylorhynchus brunneicapillus',
#  'Caracara cheriway',
#  'Carpodacus mexicanus',
#  'Charadrius vociferus',
#  'Choloepus hoffmanni',
#  'Colaptes melanochloros',
#  'Columbina passerina',
#  'Columbina picui',
#  'Conopophaga aurita',
#  'Dendroica coronata',
#  'Egretta thula',
#  'Elaenia albiceps',
#  'Falco sparverius',
#  'Furnarius rufus',
#  'Geothlypis trichas',
#  'Geotrygon montana',
#  'Hypocnemis cantator',
#  'Icterus bullockii',
#  'Ixobrychus exilis',
#  'Lanius ludovicianus',
#  'Lepus californicus',
#  'Lophospingus pusillus',
#  'Melospiza melodia',
#  'Melozone aberti',
#  'Mimus polyglottos',
#  'Molothrus ater',
#  'Myiobius barbatus',
#  'Myrmotherula hauxwelli',
#  'Nycticorax nycticorax',
#  'Oligoryzomys nigripes',
#  'Orcinus orca',
#  'Passer domesticus',
#  'Phalcoboenus chimango',
#  'Philydor erythrocercum',
#  'Pitangus sulphuratus',
#  'Poospiza nigrorufa',
#  'Porzana carolina',
#  'Procyon lotor',
#  'Pseudoseisura lophotes',
#  'Pyrocephalus rubinus',
#  'Saltator maximus',
#  'Sapajus apella',
#  'Sayornis nigricans',
#  'Stelgidopteryx serripennis',
#  'Toxostoma redivivum',
#  'Turdus amaurochalinus',
#  'Vermivora ruficapilla',
#  'Zenaida asiatica',
#  'Zenaida auriculata',
#  'Zenaida macroura',
#  'Tadorna sp',
#  'Anas platyrhynchos',
#  'Apodemus agrarius',
#  'Myodes rutilus',
#  'Alticola argentatus',
#  'Apodemus pallipes',
#  'Microtus ilaeus',
#  'Bison bonasus',
#  'Macaca sylvanus',
#  'Apodemus flavicollis',
#  'Microtus agrestis',
#  'Microtus arvalis',
#  'Apodemus sp',
#  'Myodes glareolus',
#  'Lagomorpha sp',
#  'Sciuridae sp',
#  'Acrocephalus dumetorum',
#  'Anas crecca',
#  'Bombycilla garrulus',
#  'Carduelis carduelis',
#  'Carduelis chloris',
#  'Carduelis spinus',
#  'Carpodacus erythrinus',
#  'Dendrocopos major',
#  'Emberiza citrinella',
#  'Ficedula hypoleuca',
#  'Luscinia calliope',
#  'Luscinia luscinia',
#  'Mergus merganser',
#  'Parus ater',
#  'Parus major',
#  'Parus montanus',
#  'Passer montanus',
#  'Phoenicurus phoenicurus',
#  'Phylloscopus collybita',
#  'Phylloscopus proregulus',
#  'Phylloscopus trochilus',
#  'Pyrrhula pyrrhula',
#  'Riparia riparia',
#  'Sitta europaea',
#  'Spatula clypeata',
#  'Sylvia curruca',
#  'Vanellus vanellus',
#  'Ovis orientalis',
#  'Accipiter gentilis',
#  'Anthus trivialis',
#  'Bonasa bonasia',
#  'Carduelis flammea',
#  'Clangula hyemalis',
#  'Corvus corone',
#  'Corvus monedula',
#  'Crex crex',
#  'Emberiza fucata',
#  'Fringilla coelebs',
#  'Fringilla montifringilla',
#  'Fulica atra',
#  'Jynx torquilla',
#  'Lanius collurio',
#  'Lanius cristatus',
#  'Loxia curvirostra',
#  'Melanitta fusca',
#  'Motacilla alba',
#  'Motacilla flava',
#  'Pica pica',
#  'Scolopax rusticola',
#  'Spatula querquedula',
#  'Troglodytes troglodytes',
#  'Turdus pallidus',
#  'Turdus pilaris',
#  'Turdus ruficollis',
#  'Arvicanthis niloticus',
#  'Cricetomys gambianus',
#  'Saxicola rubetra',
#  'Andropadus virens',
#  'Bycanistes sharpii',
#  'Praomys sp',
#  'Turdus libonyanus',
#  'Aegolius funereus',
#  'Erithacus rubecula',
#  'Glaucidium passerinum',
#  'Surnia ulula',
#  'Hirundo rustica',
#  'Parus caeruleus',
#  'Strix nebulosa',
#  'Ardea cinerea',
#  'Clanga clanga',
#  'Larus michahellis',
#  'Merops apiaster',
#  'Picus viridis',
#  'Streptopelia decaocto',
#  'Garrulus glandarius',
#  'Ciconia ciconia',
#  'Pandion haliaetus',
#  'Equus asinus',
#  'Acrocephalus scirpaceus',
#  'Bubo bubo',
#  'Circus aeruginosus',
#  'Delichon urbicum',
#  'Emberiza schoeniclus',
#  'Falco tinnunculus',
#  'Gypaetus barbatus',
#  'Pavo cristatus',
#  'Phoenicurus ochruros',
#  'Strix aluco',
#  'Strix uralensis',
#  'Sylvia atricapilla',
#  'Sylvia borin',
#  'Sylvia communis',
#  'Tyto alba',
#  'Alcedo atthis',
#  'Larosterna inca',
#  'Serinus canaria',
#  'Turdus sp',
#  'Asio otus',
#  'Caprimulgus europaeus',
#  'Larus ridibundus',
#  'Desmodillus auricularis',
#  'Acrocephalus schoenobaenus',
#  'Anthus pratensis',
#  'Meleagris gallopavo',
#  'Prunella modularis',
#  'Dendroica petechia',
#  'Icterus leucopteryx',
#  'Leptotila jamaicensis',
#  'Mniotilta varia',
#  'Myiopagis cotta',
#  'Parkesia noveboracensis',
#  'Tiaris bicolor',
#  'Turdus aurantius',
#  'Turdus jamaicensis',
#  'Tyrannus caudifasciatus',
#  'Vireo modestus',
#  'Anorrhinus tickelli',
#  'Larus leucophthalmus',
#  'Anser anser domesticus ',
#  'Platycercus sp',
#  'Branta canadensis',
#  'Mephitis mephitis',
#  'Bonasa umbellus',
#  'Ciconia sp',
#  'Canis familiaris',
#  'Sciurus carolinensis',
#  'Cyanocitta cristata',
#  'Corvus brachyrhynchos',
#  'Gallus domesticus',
#  'Bubulcus ibis',
#  'Aegypius monachus',
#  'Corvus frugilegus',
#  'Coracornis raveni',
#  'Cardinalis cardinalis',
#  'Fulica americana',
#  'Phalacrocorax sp',
#  'Dumetella carolinensis',
#  'Falco columbarius',
#  'Falco punctatus',
#  'Accipiter nisus',
#  'Aquila adalberti',
#  'Quiscalus quiscula',
#  'Rodent sp',
#  'Aquila fasciata',
#  'Pelophylax ridibundus',
#  'Aquila chrysaetos',
#  'Sciurus niger',
#  'Athene noctua',
#  'Chaerephon bregullae',
#  'Anaxyrus fowleri',
#  'Parus atricapillus',
#  'Arabitragus jayakari',
#  'Corvus corax',
#  'Crocodylus moreletii',
#  'Panurus biarmicus',
#  'Haliaeetus albicilla',
#  'Hylocichla mustelina',
#  'Toxostoma rufum',
#  'Parus carolinensis',
#  'Loriini sp',
#  'Capra falconeri',
#  'Pelecanus conspicillatus',
#  'Quiscalus major',
#  'Gymnogyps californianus',
#  'Asio flammeus',
#  'Coragyps atratus',
#  'Buteo swainsoni',
#  'Pelecanus occidentalis',
#  'Cygnus buccinator',
#  'Sternula albifrons',
#  'Ictinia mississippiensis',
#  'Phalacrocorax auritus',
#  'Buteo regalis',
#  'Calidris alba',
#  'Sturnidae',
#  'Charadrius melodus',
#  'Haliaeetus leucocephalus',
#  'Akodon mimus',
#  'Accipitridae sp',
#  'Larus smithsonianus',
#  'Actitis macularius',
#  'Sternula antillarum',
#  'Pelecanus erythrorhynchos',
#  'Phoenicopterus ruber',
#  'Anatidae sp',
#  'Nestor notabilis',
#  'Camelus dromedarius',
#  'Larus delawarensis',
#  'Colaptes auratus',
#  'Baeolophus bicolor',
#  'Corvus ossifragus',
#  'Accipiter striatus',
#  'Carduelis tristis',
#  'Turdus migratorius',
#  'Anisognathus somptuosus',
#  'Campylorhamphus trochilirostris',
#  'Coereba flaveola',
#  'Elaenia flavogaster',
#  'Thraupis palmarum',
#  'Turdus leucomelas',
#  'Odocoileus virginianus',
#  'Oreamnos americanus',
#  'Rangifer tarandus',
#  'Ursus maritimus',
#  'Struthio camelus',
#  'Accipiter cooperii',
#  'Agelaius tricolor',
#  'Aphelocoma californica',
#  'Ardea alba',
#  'Ardea herodias',
#  'Buteo jamaicensis',
#  'Buteo lineatus',
#  'Callipepla californica',
#  'Cistothorus palustris',
#  'Dryobates nuttallii',
#  'Euphagus cyanocephalus',
#  'Falco peregrinus',
#  'Geococcyx californianus',
#  'Lonchura punctulata',
#  'Melospiza lincolnii',
#  'Melozone crissalis',
#  'Myiarchus cinerascens',
#  'Pheucticus melanocephalus',
#  'Pica nuttalli',
#  'Tachycineta bicolor',
#  'Thryomanes bewickii',
#  'Tyrannus verticalis',
#  'Zonotrichia atricapilla',
#  'Zonotrichia leucophrys',
#  'Acrocephalus palustris',
#  'Locustella luscinioides',
#  'Saguinus geoffroyi',
#  'Primate sp',
#  'Erythrocebus patas',
#  'Alouatta caraya',
#  'Alouatta guariba',
#  'Chlorocebus aethiops',
#  'Alouatta sara',
#  'Colobus guereza',
#  'Aotus sp',
#  'Callithrix jacchus',
#  'Macaca fascicularis',
#  'Pongo pygmaeus',
#  'Sapajus libidinosus']

# %%
# Count of host species for each virus
virus_host_count=df.groupby('Virus').agg({'Scientific Name' : 'count'})
virus_host_count
# Out:
#                                   Scientific Name
# Virus
# Apoi virus                                      4
# Bagaza virus                                    2
# Banzi virus                                     2
# Bouboui virus                                   1
# Bussuquara virus                                3
# Cacipacore virus                                1
# Dakar bat virus                                 5
# Dengue virus                                   27
# Entebbe bat virus                               6
# Iguape virus                                    1
# Ilheus virus                                    5
# Japanese encephalitis virus                    25
# Koutango virus                                  1
# Kunjin virus                                    3
# Kyasanur forest virus                           6
# Louping-ill virus                              13
# Modoc virus                                     3
# Murray Valley encephalitis virus                3
# Omsk hemorrhagic fever virus                    3
# Rio Bravo virus                                 9
# Rocio virus                                     2
# St. Louis Encephalitis virus                   72
# Tembusu virus                                   2
# Tickborne encephalitis virus                   84
# Uganda S virus                                  7
# Usutu virus                                    65
# Wesselsbron virus                               3
# West Nile virus                               194
# Yellow fever virus                             11
# Zika virus                                      7

# %%
# Most diverse viruses (viruses with most unique host species)
virus_host_count.nlargest(5, "Scientific Name")
# Out:
#                               Scientific Name
# Virus
# West Nile virus                           194
# Tickborne encephalitis virus               84
# St. Louis Encephalitis virus               72
# Usutu virus                                65
# Dengue virus                               27

# %% [markdown]
# # Metadata
#
# ## Given that we are interested in the metadata associated with these host species, we will import datasets associated with the metadata for both bird and mammalian species.

# %% [markdown]
# 1. Birds

# %%
birds_meta = pd.read_excel('/content/Handbook of the Birds of the World and BirdLife International Digital Checklist of the Birds of the World_Version_9.xlsx')
birds_meta
# Out:
#            Seq.  Subsp. Seq.             Order    Family name     Family  \
# 0           1.0          0.0  STRUTHIONIFORMES  Struthionidae  Ostriches
# 1           1.0          1.0               NaN            NaN        NaN
# 2           1.0          2.0               NaN            NaN        NaN
# 3           1.0          3.0               NaN            NaN        NaN
# 4           1.0          4.0               NaN            NaN        NaN
# ...         ...          ...               ...            ...        ...
# 33260  102032.0          NaN     PASSERIFORMES     Thraupidae   Tanagers
# 33261  102033.0          NaN     PASSERIFORMES     Thraupidae   Tanagers
# 33262  102034.0          NaN     PASSERIFORMES     Thraupidae   Tanagers
# 33263  102035.0          NaN     PASSERIFORMES     Thraupidae   Tanagers
# 33264  102036.0          NaN     PASSERIFORMES     Thraupidae   Tanagers
#
#         Subfamily Tribe     Common name             Scientific name  \
# 0             NaN   NaN  Common Ostrich            Struthio camelus
# 1             NaN   NaN             NaN   Struthio camelus syriacus
# 2             NaN   NaN             NaN    Struthio camelus camelus
# 3             NaN   NaN             NaN  Struthio camelus massaicus
# 4             NaN   NaN             NaN  Struthio camelus australis
# ...           ...   ...             ...                         ...
# 33260  Thraupinae   NaN             NaN          Tangara cyanoptera
# 33261  Thraupinae   NaN             NaN            Tangara vassorii
# 33262  Thraupinae   NaN             NaN               Tangara velia
# 33263  Thraupinae   NaN             NaN        Tangara brasiliensis
# 33264  Thraupinae   NaN             NaN           Tangara cucullata
#
#                  Authority 2024 IUCN Red List category Synonyms  \
# 0           Linnaeus, 1758                          LC      NaN
# 1                      NaN                         NaN      NaN
# 2                      NaN                         NaN      NaN
# 3                      NaN                         NaN      NaN
# 4                      NaN                         NaN      NaN
# ...                    ...                         ...      ...
# 33260     (Swainson, 1834)                          NR      NaN
# 33261  (Boissonneau, 1840)                          NR      NaN
# 33262     (Linnaeus, 1758)                          NR      NaN
# 33263     (Linnaeus, 1766)                          NR      NaN
# 33264     (Swainson, 1834)                          NR      NaN
#
#       Alternative common names  \
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
# ...                        ...
# 33260                      NaN
# 33261                      NaN
# 33262                      NaN
# 33263                      NaN
# 33264                      NaN
#
#                                      Taxonomic source(s)    SISRecID  \
# 0      del Hoyo, J., Collar, N.J., Christie, D.A., El...  45020636.0
# 1                                                    NaN         NaN
# 2                                                    NaN         NaN
# 3                                                    NaN         NaN
# 4                                                    NaN         NaN
# ...                                                  ...         ...
# 33260  SACC (2005 & updates); Sibley & Monroe (1990, ...  22722950.0
# 33261  SACC (2005 & updates); Sibley & Monroe (1990, ...  22722933.0
# 33262  SACC (2005 & updates); Sibley & Monroe (1990, ...  22731274.0
# 33263                                Stotz et al. (1996)  22731781.0
# 33264  AOU (1998 & supplements); Sibley & Monroe (199...  22722887.0
#
#        SpcRecID\n(used before SISRecID)    SubsppID
# 0                             1016860.0         NaN
# 1                                   NaN  45020636_1
# 2                                   NaN  45020636_2
# 3                                   NaN  45020636_3
# 4                                   NaN  45020636_4
# ...                                 ...         ...
# 33260                            9428.0         NaN
# 33261                            9423.0         NaN
# 33262                           31308.0         NaN
# 33263                           31402.0         NaN
# 33264                            9408.0         NaN
#
# [33265 rows x 17 columns]

# %% [markdown]
# The data for birds is at subspecies level. It means that there is species name represented by column `Seq.`. All rows in same number represent one species.

# %% [markdown]
# 2. Mammals

# %% [markdown]
# ## Similarly, read file for mammals metadata.

# %%
loc='/content/IUCN Mammals, Birds, Reptiles, and Amphibians.csv'
mammals_meta = pd.read_csv(loc, encoding='latin-1')
mammals_meta.head()
# Out:
#    Species ID   Kingdom    Phylum     Class             Order       Family  \
# 0     42641.0  ANIMALIA  CHORDATA  MAMMALIA          RODENTIA      MURIDAE
# 1  22687170.0  ANIMALIA  CHORDATA      AVES  CAPRIMULGIFORMES  TROCHILIDAE
# 2     17879.0  ANIMALIA  CHORDATA  MAMMALIA          RODENTIA      MURIDAE
# 3  47760825.0  ANIMALIA  CHORDATA  MAMMALIA          RODENTIA   CRICETIDAE
# 4     42656.0  ANIMALIA  CHORDATA  MAMMALIA          RODENTIA  ABROCOMIDAE
#
#           Genus    Species                  Authority  Infraspecific rank  \
# 0     Abditomys   latidens            (Sanborn, 1952)                 NaN
# 1      Abeillia   abeillei  (Lesson & DeLattre, 1839)                 NaN
# 2   Abeomelomys      sevia    (Tate & Archbold, 1935)                 NaN
# 3  Abrawayaomys    ruschii         Cunha & Cruz, 1979                 NaN
# 4      Abrocoma  bennettii           Waterhouse, 1837                 NaN
#
#    ...                             Synonyms  \
# 0  ...                                  NaN
# 1  ...                                  NaN
# 2  ...  Melomys sevia|Pogonomelomys sevia
# 3  ...                                  NaN
# 4  ...                                  NaN
#
#                                   Common names (Eng)  Common names (Fre)  \
# 0                            Luzon Broad-toothed Rat                 NaN
# 1                        Emerald-chinned Hummingbird                 NaN
# 2  Menzies' Mouse, Menzies's Mouse, Highland Brus...                 NaN
# 3                                       Ruschi's Rat                 NaN
# 4                           Bennett's Chinchilla Rat                 NaN
#
#   Common names (Spa) Red List status Red List criteria  \
# 0                NaN              DD               NaN
# 1                NaN              LC               NaN
# 2                NaN              LC               NaN
# 3                NaN              LC               NaN
# 4                NaN              LC               NaN
#
#   Red List criteria version Year assessed Population trend  Petitioned
# 0                       3.1        2008.0          unknown           N
# 1                       3.1        2012.0       decreasing           N
# 2                       3.1        2016.0          unknown           N
# 3                       3.1        2016.0          unknown           N
# 4                       3.1        2016.0          unknown           N
#
# [5 rows x 23 columns]

# %% [markdown]
# ## For both birds and mammals answer the following questions.
# 1. Size of the datasets
# 2. For birds, filter the dataset using species-level rows only. Hint. Column `Subsp. Seq.` value of 0 indicates the main species name
# 3. How many bird species and mammal species are present in data frames?

# %% [markdown]
# Bird Data

# %%
# 1. Size
birds_meta.shape
# Out:
# (33265, 17)

# %%
# 2. Filter using the species-level rows
Species_level_only_birds= birds_meta[birds_meta['Subsp. Seq.'] == 0]
Species_level_only_birds
Bird_filter=Species_level_only_birds.groupby('Scientific name')
Bird_filter

# %%
#3. How many bird species are present
Species_level_only_birds['Scientific name'].nunique()
# Out:
# 11198

# %% [markdown]
# Mammal Dataset

# %%
# 1. Size
mammals_meta.shape
# Out:
# (16081, 23)

# %%
# 2. Filter using the species-level rows
mammal_filter=mammals_meta.groupby('Species')
mammal_filter

# %%
#3. How many mammal species are present
mammals_meta.Species.nunique()
# Out:
# 8779

# %% [markdown]
# # Database Integration Exercise
# The main objective of this exercise is to create a comprehensive database by combining three data frames. Follow these steps  n your analysis.

# %% [markdown]
# ## Create a concept map:
# * Illustrate the relationships between the three data frames.
# * Identify and highlight the Primary Keys in each data frame.
# * Use a diagramming tool (e.g., PowerPoint, LucidChart, or Draw.io) to create a visual representation of these connections.
# * Pay special attention to how you plan to merge the Mammals and Birds data frames.

# %%
Added in models folder

# %% [markdown]
# ## Perform a vertical join of Mammals and Birds data frames:
# * Identify and select only the common columns present in both data frames.
# * Use `pd.concat()` or `df.append()` to create a larger dataframe called **metadata**.
# * Ensure the resulting dataframe has the correct number of rows and columns.

# %%
#rename bird columns
Species_level_only_birds = Species_level_only_birds.rename(columns={'SISRecID': 'Species ID', '2024 IUCN Red List category': 'Red List status'})

#add bird class
Species_level_only_birds['Class'] = 'AVES'

#create scientific name column
mammals_meta['Scientific name']= mammals_meta['Genus'] + ' ' + mammals_meta['Species']

#rename mammal columns
mammals_meta = mammals_meta.rename(columns={'Family': 'Family name', 'Common names (Eng)': 'Common name',})

# %%
#merge spreadsheets
metadata_all_columns=pd.concat([Species_level_only_birds, mammals_meta], axis=0, ignore_index=True)
metadata_all_columns
# Out:
#        Seq.  Subsp. Seq.             Order    Family name     Family  \
# 0       1.0          0.0  STRUTHIONIFORMES  Struthionidae  Ostriches
# 1       2.0          0.0  STRUTHIONIFORMES  Struthionidae  Ostriches
# 2       3.0          0.0  STRUTHIONIFORMES        Rheidae      Rheas
# 3       4.0          0.0  STRUTHIONIFORMES        Rheidae      Rheas
# 4       5.0          0.0  STRUTHIONIFORMES      Tinamidae   Tinamous
# ...     ...          ...               ...            ...        ...
# 27280   NaN          NaN   CETARTIODACTYLA      CAMELIDAE        NaN
# 27281   NaN          NaN     PASSERIFORMES      STURNIDAE        NaN
# 27282   NaN          NaN          RODENTIA        MURIDAE        NaN
# 27283   NaN          NaN   CETARTIODACTYLA         SUIDAE        NaN
# 27284   NaN          NaN          RODENTIA        MURIDAE        NaN
#
#       Subfamily Tribe             Common name         Scientific name  \
# 0           NaN   NaN          Common Ostrich        Struthio camelus
# 1           NaN   NaN          Somali Ostrich  Struthio molybdophanes
# 2           NaN   NaN            Greater Rhea          Rhea americana
# 3           NaN   NaN             Lesser Rhea            Rhea pennata
# 4           NaN   NaN  Tawny-breasted Tinamou      Nothocercus julius
# ...         ...   ...                     ...                     ...
# 27280       NaN   NaN                     NaN           Vicugna pacos
# 27281       NaN   NaN                     NaN                     NaN
# 27282       NaN   NaN                     NaN                     NaN
# 27283       NaN   NaN                     NaN   Sus scrofa domesticus
# 27284       NaN   NaN                     NaN        Hylomyscus pamfi
#
#                Authority  ... Infraspecific name Infraspecific authority  \
# 0         Linnaeus, 1758  ...                NaN                     NaN
# 1        Reichenow, 1883  ...                NaN                     NaN
# 2       (Linnaeus, 1758)  ...                NaN                     NaN
# 3        d'Orbigny, 1834  ...                NaN                     NaN
# 4      (Bonaparte, 1854)  ...                NaN                     NaN
# ...                  ...  ...                ...                     ...
# 27280                NaN  ...                NaN                     NaN
# 27281                NaN  ...                NaN                     NaN
# 27282                NaN  ...                NaN                     NaN
# 27283                NaN  ...                NaN                     NaN
# 27284                NaN  ...                NaN                     NaN
#
#       Stock/subpopulation Common names (Fre)  Common names (Spa)  \
# 0                     NaN                NaN                 NaN
# 1                     NaN                NaN                 NaN
# 2                     NaN                NaN                 NaN
# 3                     NaN                NaN                 NaN
# 4                     NaN                NaN                 NaN
# ...                   ...                ...                 ...
# 27280                 NaN                NaN                 NaN
# 27281                 NaN                NaN                 NaN
# 27282                 NaN                NaN                 NaN
# 27283                 NaN                NaN                 NaN
# 27284                 NaN                NaN                 NaN
#
#        Red List criteria Red List criteria version Year assessed  \
# 0                    NaN                       NaN           NaN
# 1                    NaN                       NaN           NaN
# 2                    NaN                       NaN           NaN
# 3                    NaN                       NaN           NaN
# 4                    NaN                       NaN           NaN
# ...                  ...                       ...           ...
# 27280                NaN                       NaN           NaN
# 27281                NaN                       NaN           NaN
# 27282                NaN                       NaN           NaN
# 27283                NaN                       NaN           NaN
# 27284                NaN                       NaN           NaN
#
#       Population trend Petitioned
# 0                  NaN        NaN
# 1                  NaN        NaN
# 2                  NaN        NaN
# 3                  NaN        NaN
# 4                  NaN        NaN
# ...                ...        ...
# 27280              NaN        NaN
# 27281              NaN        NaN
# 27282              NaN        NaN
# 27283              NaN        NaN
# 27284              NaN        NaN
#
# [27285 rows x 33 columns]

# %%
#select only overlapping columns and rename
metadata= metadata_all_columns[['Species ID','Class', 'Order', 'Family name', 'Common name', 'Scientific name', 'Authority', 'Synonyms', 'Red List status']]
metadata
# Out:
#        Species ID     Class             Order    Family name  \
# 0      45020636.0      AVES  STRUTHIONIFORMES  Struthionidae
# 1      22732795.0      AVES  STRUTHIONIFORMES  Struthionidae
# 2      22678073.0      AVES  STRUTHIONIFORMES        Rheidae
# 3      22678081.0      AVES  STRUTHIONIFORMES        Rheidae
# 4      22678157.0      AVES  STRUTHIONIFORMES      Tinamidae
# ...           ...       ...               ...            ...
# 27280         NaN  MAMMALIA   CETARTIODACTYLA      CAMELIDAE
# 27281         NaN      AVES     PASSERIFORMES      STURNIDAE
# 27282         NaN  MAMMALIA          RODENTIA        MURIDAE
# 27283         NaN  MAMMALIA   CETARTIODACTYLA         SUIDAE
# 27284    972559.0  MAMMALIA          RODENTIA        MURIDAE
#
#                   Common name         Scientific name          Authority  \
# 0              Common Ostrich        Struthio camelus     Linnaeus, 1758
# 1              Somali Ostrich  Struthio molybdophanes    Reichenow, 1883
# 2                Greater Rhea          Rhea americana   (Linnaeus, 1758)
# 3                 Lesser Rhea            Rhea pennata    d'Orbigny, 1834
# 4      Tawny-breasted Tinamou      Nothocercus julius  (Bonaparte, 1854)
# ...                       ...                     ...                ...
# 27280                     NaN           Vicugna pacos                NaN
# 27281                     NaN                     NaN                NaN
# 27282                     NaN                     NaN                NaN
# 27283                     NaN   Sus scrofa domesticus                NaN
# 27284                     NaN        Hylomyscus pamfi                NaN
#
#       Synonyms Red List status
# 0          NaN              LC
# 1          NaN              VU
# 2          NaN              NT
# 3          NaN              LC
# 4          NaN              LC
# ...        ...             ...
# 27280      NaN             NaN
# 27281      NaN             NaN
# 27282      NaN             NaN
# 27283      NaN             NaN
# 27284      NaN             NaN
#
# [27285 rows x 9 columns]

# %%
#check that merge was done correctly
metadata.shape
# Out:
# (27285, 9)

# %% [markdown]
# ## Merge the metadata dataframe with the Flavivirus dataframe:
# * Experiment with different join types: `inner`, `outer`, `left`, and `right`.
# * For each join type, record the resulting dataframe's shape (rows and columns).
# * Determine the **theoretically correct size of the merged dataframe if done manually**.
# * Compare the results of each join type with the expected outcome.
# * Choose the most appropriate join type based on your analysis.

# %%
#rename and inner merge
metadata=metadata.rename(columns={'Scientific name' : 'Scientific Name'})
merged_df_inner=pd.merge(df, metadata, on='Scientific Name', how='inner')
merged_df_inner
# Out:
#      sr no.         Virus      Scientific Name  \
# 0         3    Apoi virus        Rattus rattus
# 1         2    Apoi virus     Myodes rufocanus
# 2         0    Apoi virus   Apodemus argenteus
# 3         1    Apoi virus   Apodemus speciosus
# 4         4  Bagaza virus       Alectoris rufa
# ..      ...           ...                  ...
# 867     561    Zika virus   Callithrix jacchus
# 868     565    Zika virus       Macaca mulatta
# 869     564    Zika virus  Macaca fascicularis
# 870     566    Zika virus       Pongo pygmaeus
# 871     567    Zika virus  Sapajus libidinosus
#
#                                                Authors  Year  \
# 0    C. M. Baak-Baak, N. Cigarroa-Toledo, O. M. Tor...  2016
# 1                                          CDC Arbocat   NaN
# 2                   J. S. Mackenzie and D. T. Williams  2009
# 3                   J. S. Mackenzie and D. T. Williams  2009
# 4    D. Buitrago, A. Rocha, C. Tena-Tomas, M. Vigo,...  2012
# ..                                                 ...   ...
# 867  C. Akoua-Koffi, K. D. Ekra, A. B. Kone, N. S. ...  2002
# 868                                        E. B. Hayes  2009
# 869  G. H. Leung, R. W. Baird, J. Druce and N. M. A...  2015
# 870  N. D. Wolfe, A. M. Kilbourn, W. B. Karesh, H. ...  2001
# 871  S. Favoretto, D. Araujo, D. Oliveira, N. Duart...  2016
#
#                                 Title/accession number  \
# 0    New Records of Ectoparasites Echinolaelaps ech...
# 1                                          CDC Arbocat
# 2    The zoonotic flaviviruses of southern, south-e...
# 3    The zoonotic flaviviruses of southern, south-e...
# 4    Real-time fluorogenic reverse transcription po...
# ..                                                 ...
# 867  [Detection and management of the yellow fever ...
# 868                          Zika virus outside Africa
# 869  Zika Virus Infection in Australia Following a ...
# 870  Sylvatic transmission of arboviruses among Bor...
# 871  First detection of Zika virus in neotropical p...
#
#                                                Journal  Issue Volume    Pages  \
# 0                            Southwestern Entomologist    NaN    NaN      NaN
# 1                                                  NaN    NaN    NaN      NaN
# 2                               Zoonoses Public Health   56.0    6-7   338-56
# 3                               Zoonoses Public Health   56.0    6-7   338-56
# 4                                   J Vet Diagn Invest   24.0      5   959-63
# ..                                                 ...    ...    ...      ...
# 867                                    Med Trop (Mars)   62.0      3    305-9
# 868                                   Emerg Infect Dis   15.0      9  1347-50
# 869           Southeast Asian J Trop Med Public Health   46.0      3    460-4
# 870  American Journal of Tropical Medicine and Hygiene   64.0    5-6  310-316
# 871                                            bioRxiv    NaN    NaN    49395
#
#      Species ID     Class        Order      Family name  \
# 0       19360.0  MAMMALIA     RODENTIA          MURIDAE
# 1        4974.0  MAMMALIA     RODENTIA       CRICETIDAE
# 2       42642.0  MAMMALIA     RODENTIA          MURIDAE
# 3        1903.0  MAMMALIA     RODENTIA          MURIDAE
# 4    22678711.0      AVES  GALLIFORMES      Phasianidae
# ..          ...       ...          ...              ...
# 867     41518.0  MAMMALIA     PRIMATES   CALLITRICHIDAE
# 868     12554.0  MAMMALIA     PRIMATES  CERCOPITHECIDAE
# 869     12551.0  MAMMALIA     PRIMATES  CERCOPITHECIDAE
# 870     17975.0  MAMMALIA     PRIMATES        HOMINIDAE
# 871    136346.0  MAMMALIA     PRIMATES          CEBIDAE
#
#                                            Common name           Authority  \
# 0             House Rat, Ship Rat, Roof Rat, Black Rat    (Linnaeus, 1758)
# 1    Grey Red-backed Vole, Grey-sided Vole, Gray Re...   (Sundevall, 1846)
# 2                           Small Japanese Field Mouse    (Temminck, 1844)
# 3                           Large Japanese Field Mouse    (Temminck, 1844)
# 4                                 Red-legged Partridge    (Linnaeus, 1758)
# ..                                                 ...                 ...
# 867         Common Marmoset, White-tufted-ear Marmoset    (Linnaeus, 1758)
# 868                      Rhesus Monkey, Rhesus Macaque  (Zimmermann, 1780)
# 869  Nicobar Crab-eating Macaque, Nicobar Cynomolgu...     (Raffles, 1821)
# 870                                  Bornean Orangutan    (Linnaeus, 1760)
# 871           Bearded Capuchin, Black-striped Capuchin        (Spix, 1823)
#
#                                               Synonyms Red List status
# 0                                                  NaN              LC
# 1    Clethrionomys rufocanus  |Clethrionomys sikota...              LC
# 2                                                  NaN              LC
# 3                   Micromys speciosus subspecies ainu              LC
# 4                                                  NaN              NT
# ..                                                 ...             ...
# 867                                                NaN              LC
# 868  Macaca brachyurus  |Macaca brevicaudatus  |Mac...              LC
# 869                                                NaN              LC
# 870                                     Simia pygmaeus              CR
# 871                                  Cebus libidinosus              LC
#
# [872 rows x 18 columns]

# %%
merged_df_inner.shape
# Out:
# (872, 18)

# %%
#outer merge
merged_df_outer=pd.merge(df, metadata, on='Scientific Name', how='outer')
merged_df_outer
# Out:
#        sr no. Virus       Scientific Name Authors Year Title/accession number  \
# 0         NaN   NaN    Abditomys latidens     NaN  NaN                    NaN
# 1         NaN   NaN     Abeillia abeillei     NaN  NaN                    NaN
# 2         NaN   NaN     Abeillia abeillei     NaN  NaN                    NaN
# 3         NaN   NaN     Abeomelomys sevia     NaN  NaN                    NaN
# 4         NaN   NaN  Abrawayaomys ruschii     NaN  NaN                    NaN
# ...       ...   ...                   ...     ...  ...                    ...
# 27509     NaN   NaN        chiroptera sp.     NaN  NaN                    NaN
# 27510     NaN   NaN                   NaN     NaN  NaN                    NaN
# 27511     NaN   NaN                   NaN     NaN  NaN                    NaN
# 27512     NaN   NaN                   NaN     NaN  NaN                    NaN
# 27513     NaN   NaN                   NaN     NaN  NaN                    NaN
#
#       Journal  Issue Volume Pages  Species ID     Class             Order  \
# 0         NaN    NaN    NaN   NaN     42641.0  MAMMALIA          RODENTIA
# 1         NaN    NaN    NaN   NaN  22687170.0      AVES  CAPRIMULGIFORMES
# 2         NaN    NaN    NaN   NaN  22687170.0      AVES  CAPRIMULGIFORMES
# 3         NaN    NaN    NaN   NaN     17879.0  MAMMALIA          RODENTIA
# 4         NaN    NaN    NaN   NaN  47760825.0  MAMMALIA          RODENTIA
# ...       ...    ...    ...   ...         ...       ...               ...
# 27509     NaN    NaN    NaN   NaN         NaN  MAMMALIA        CHIROPTERA
# 27510     NaN    NaN    NaN   NaN         NaN  MAMMALIA          RODENTIA
# 27511     NaN    NaN    NaN   NaN         NaN      AVES     PASSERIFORMES
# 27512     NaN    NaN    NaN   NaN         NaN      AVES     PASSERIFORMES
# 27513     NaN    NaN    NaN   NaN         NaN  MAMMALIA          RODENTIA
#
#           Family name                                        Common name  \
# 0             MURIDAE                            Luzon Broad-toothed Rat
# 1         Trochilidae                        Emerald-chinned Hummingbird
# 2         TROCHILIDAE                        Emerald-chinned Hummingbird
# 3             MURIDAE  Menzies' Mouse, Menzies's Mouse, Highland Brus...
# 4          CRICETIDAE                                       Ruschi's Rat
# ...               ...                                                ...
# 27509  PHYLLOSTOMIDAE                                                NaN
# 27510         MURIDAE                                                NaN
# 27511       STURNIDAE                                                NaN
# 27512       STURNIDAE                                                NaN
# 27513         MURIDAE                                                NaN
#
#                        Authority                             Synonyms  \
# 0                (Sanborn, 1952)                                  NaN
# 1      (Lesson & DeLattre, 1839)                                  NaN
# 2      (Lesson & DeLattre, 1839)                                  NaN
# 3        (Tate & Archbold, 1935)  Melomys sevia|Pogonomelomys sevia
# 4             Cunha & Cruz, 1979                                  NaN
# ...                          ...                                  ...
# 27509                        NaN                                  NaN
# 27510                        NaN                                  NaN
# 27511                        NaN                                  NaN
# 27512                        NaN                                  NaN
# 27513                        NaN                                  NaN
#
#       Red List status
# 0                  DD
# 1                  LC
# 2                  LC
# 3                  LC
# 4                  LC
# ...               ...
# 27509             NaN
# 27510             NaN
# 27511             NaN
# 27512             NaN
# 27513             NaN
#
# [27514 rows x 18 columns]

# %%
merged_df_outer.shape
# Out:
# (27514, 18)

# %%
#left merge
merged_df_left=pd.merge(df, metadata, on='Scientific Name', how='left')
merged_df_left=merged_df_left.drop_duplicates(subset='sr no.', keep='first')
merged_df_left
# Out:
#      sr no.         Virus      Scientific Name  \
# 0         3    Apoi virus        Rattus rattus
# 1         2    Apoi virus     Myodes rufocanus
# 2         0    Apoi virus   Apodemus argenteus
# 3         1    Apoi virus   Apodemus speciosus
# 4         4  Bagaza virus       Alectoris rufa
# ..      ...           ...                  ...
# 876     561    Zika virus   Callithrix jacchus
# 877     565    Zika virus       Macaca mulatta
# 878     564    Zika virus  Macaca fascicularis
# 879     566    Zika virus       Pongo pygmaeus
# 880     567    Zika virus  Sapajus libidinosus
#
#                                                Authors  Year  \
# 0    C. M. Baak-Baak, N. Cigarroa-Toledo, O. M. Tor...  2016
# 1                                          CDC Arbocat   NaN
# 2                   J. S. Mackenzie and D. T. Williams  2009
# 3                   J. S. Mackenzie and D. T. Williams  2009
# 4    D. Buitrago, A. Rocha, C. Tena-Tomas, M. Vigo,...  2012
# ..                                                 ...   ...
# 876  C. Akoua-Koffi, K. D. Ekra, A. B. Kone, N. S. ...  2002
# 877                                        E. B. Hayes  2009
# 878  G. H. Leung, R. W. Baird, J. Druce and N. M. A...  2015
# 879  N. D. Wolfe, A. M. Kilbourn, W. B. Karesh, H. ...  2001
# 880  S. Favoretto, D. Araujo, D. Oliveira, N. Duart...  2016
#
#                                 Title/accession number  \
# 0    New Records of Ectoparasites Echinolaelaps ech...
# 1                                          CDC Arbocat
# 2    The zoonotic flaviviruses of southern, south-e...
# 3    The zoonotic flaviviruses of southern, south-e...
# 4    Real-time fluorogenic reverse transcription po...
# ..                                                 ...
# 876  [Detection and management of the yellow fever ...
# 877                          Zika virus outside Africa
# 878  Zika Virus Infection in Australia Following a ...
# 879  Sylvatic transmission of arboviruses among Bor...
# 880  First detection of Zika virus in neotropical p...
#
#                                                Journal  Issue Volume    Pages  \
# 0                            Southwestern Entomologist    NaN    NaN      NaN
# 1                                                  NaN    NaN    NaN      NaN
# 2                               Zoonoses Public Health   56.0    6-7   338-56
# 3                               Zoonoses Public Health   56.0    6-7   338-56
# 4                                   J Vet Diagn Invest   24.0      5   959-63
# ..                                                 ...    ...    ...      ...
# 876                                    Med Trop (Mars)   62.0      3    305-9
# 877                                   Emerg Infect Dis   15.0      9  1347-50
# 878           Southeast Asian J Trop Med Public Health   46.0      3    460-4
# 879  American Journal of Tropical Medicine and Hygiene   64.0    5-6  310-316
# 880                                            bioRxiv    NaN    NaN    49395
#
#      Species ID     Class        Order      Family name  \
# 0       19360.0  MAMMALIA     RODENTIA          MURIDAE
# 1        4974.0  MAMMALIA     RODENTIA       CRICETIDAE
# 2       42642.0  MAMMALIA     RODENTIA          MURIDAE
# 3        1903.0  MAMMALIA     RODENTIA          MURIDAE
# 4    22678711.0      AVES  GALLIFORMES      Phasianidae
# ..          ...       ...          ...              ...
# 876     41518.0  MAMMALIA     PRIMATES   CALLITRICHIDAE
# 877     12554.0  MAMMALIA     PRIMATES  CERCOPITHECIDAE
# 878     12551.0  MAMMALIA     PRIMATES  CERCOPITHECIDAE
# 879     17975.0  MAMMALIA     PRIMATES        HOMINIDAE
# 880    136346.0  MAMMALIA     PRIMATES          CEBIDAE
#
#                                            Common name           Authority  \
# 0             House Rat, Ship Rat, Roof Rat, Black Rat    (Linnaeus, 1758)
# 1    Grey Red-backed Vole, Grey-sided Vole, Gray Re...   (Sundevall, 1846)
# 2                           Small Japanese Field Mouse    (Temminck, 1844)
# 3                           Large Japanese Field Mouse    (Temminck, 1844)
# 4                                 Red-legged Partridge    (Linnaeus, 1758)
# ..                                                 ...                 ...
# 876         Common Marmoset, White-tufted-ear Marmoset    (Linnaeus, 1758)
# 877                      Rhesus Monkey, Rhesus Macaque  (Zimmermann, 1780)
# 878  Nicobar Crab-eating Macaque, Nicobar Cynomolgu...     (Raffles, 1821)
# 879                                  Bornean Orangutan    (Linnaeus, 1760)
# 880           Bearded Capuchin, Black-striped Capuchin        (Spix, 1823)
#
#                                               Synonyms Red List status
# 0                                                  NaN              LC
# 1    Clethrionomys rufocanus  |Clethrionomys sikota...              LC
# 2                                                  NaN              LC
# 3                   Micromys speciosus subspecies ainu              LC
# 4                                                  NaN              NT
# ..                                                 ...             ...
# 876                                                NaN              LC
# 877  Macaca brachyurus  |Macaca brevicaudatus  |Mac...              LC
# 878                                                NaN              LC
# 879                                     Simia pygmaeus              CR
# 880                                  Cebus libidinosus              LC
#
# [566 rows x 18 columns]

# %%
merged_df_left.shape
# Out:
# (566, 18)

# %%
#right merge
merged_df_right=pd.merge(df, metadata, on='Scientific Name', how='right')
merged_df_right
# Out:
#        sr no.            Virus         Scientific Name  \
# 0       522.0  West Nile virus        Struthio camelus
# 1         NaN              NaN  Struthio molybdophanes
# 2         NaN              NaN          Rhea americana
# 3         NaN              NaN            Rhea pennata
# 4         NaN              NaN      Nothocercus julius
# ...       ...              ...                     ...
# 27500     NaN              NaN           Vicugna pacos
# 27501     NaN              NaN                     NaN
# 27502     NaN              NaN                     NaN
# 27503     NaN              NaN   Sus scrofa domesticus
# 27504     NaN              NaN        Hylomyscus pamfi
#
#                           Authors  Year  \
# 0      M. Venter and R. Swanepoel  2010
# 1                             NaN   NaN
# 2                             NaN   NaN
# 3                             NaN   NaN
# 4                             NaN   NaN
# ...                           ...   ...
# 27500                         NaN   NaN
# 27501                         NaN   NaN
# 27502                         NaN   NaN
# 27503                         NaN   NaN
# 27504                         NaN   NaN
#
#                                   Title/accession number  \
# 0      West Nile virus lineage 2 as a cause of zoonot...
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 27500                                                NaN
# 27501                                                NaN
# 27502                                                NaN
# 27503                                                NaN
# 27504                                                NaN
#
#                          Journal  Issue Volume   Pages  Species ID     Class  \
# 0      Vector Borne Zoonotic Dis   10.0      7  659-64  45020636.0      AVES
# 1                            NaN    NaN    NaN     NaN  22732795.0      AVES
# 2                            NaN    NaN    NaN     NaN  22678073.0      AVES
# 3                            NaN    NaN    NaN     NaN  22678081.0      AVES
# 4                            NaN    NaN    NaN     NaN  22678157.0      AVES
# ...                          ...    ...    ...     ...         ...       ...
# 27500                        NaN    NaN    NaN     NaN         NaN  MAMMALIA
# 27501                        NaN    NaN    NaN     NaN         NaN      AVES
# 27502                        NaN    NaN    NaN     NaN         NaN  MAMMALIA
# 27503                        NaN    NaN    NaN     NaN         NaN  MAMMALIA
# 27504                        NaN    NaN    NaN     NaN    972559.0  MAMMALIA
#
#                   Order    Family name             Common name  \
# 0      STRUTHIONIFORMES  Struthionidae          Common Ostrich
# 1      STRUTHIONIFORMES  Struthionidae          Somali Ostrich
# 2      STRUTHIONIFORMES        Rheidae            Greater Rhea
# 3      STRUTHIONIFORMES        Rheidae             Lesser Rhea
# 4      STRUTHIONIFORMES      Tinamidae  Tawny-breasted Tinamou
# ...                 ...            ...                     ...
# 27500   CETARTIODACTYLA      CAMELIDAE                     NaN
# 27501     PASSERIFORMES      STURNIDAE                     NaN
# 27502          RODENTIA        MURIDAE                     NaN
# 27503   CETARTIODACTYLA         SUIDAE                     NaN
# 27504          RODENTIA        MURIDAE                     NaN
#
#                Authority Synonyms Red List status
# 0         Linnaeus, 1758      NaN              LC
# 1        Reichenow, 1883      NaN              VU
# 2       (Linnaeus, 1758)      NaN              NT
# 3        d'Orbigny, 1834      NaN              LC
# 4      (Bonaparte, 1854)      NaN              LC
# ...                  ...      ...             ...
# 27500                NaN      NaN             NaN
# 27501                NaN      NaN             NaN
# 27502                NaN      NaN             NaN
# 27503                NaN      NaN             NaN
# 27504                NaN      NaN             NaN
#
# [27505 rows x 18 columns]

# %%
merged_df_right.shape
# Out:
# (27505, 18)

# %% [markdown]
# You should merge left as with the correction code, it is similar to 570, which is the correct number. It makes sense to merge left, because then you are merging onto the virus data, which should be the reference.

# %% [markdown]
# ### Create a pivote table,
# 1. Rows are virueses
# 2. Columns are Taxonomic orders
# 3. Values are number of unique host species

# %%
merged_df_left.pivot_table(index='Virus', columns='Order', values='Scientific Name', aggfunc='nunique')
# Out:
# Order                             ACCIPITRIFORMES  ANSERIFORMES  \
# Virus
# Apoi virus                                    NaN           NaN
# Bagaza virus                                  NaN           NaN
# Banzi virus                                   NaN           NaN
# Bouboui virus                                 NaN           NaN
# Bussuquara virus                              NaN           NaN
# Cacipacore virus                              NaN           NaN
# Dakar bat virus                               NaN           NaN
# Dengue virus                                  NaN           NaN
# Entebbe bat virus                             NaN           NaN
# Iguape virus                                  NaN           NaN
# Ilheus virus                                  NaN           NaN
# Japanese encephalitis virus                   NaN           NaN
# Koutango virus                                NaN           NaN
# Kunjin virus                                  NaN           NaN
# Kyasanur forest virus                         NaN           NaN
# Louping-ill virus                             NaN           NaN
# Modoc virus                                   NaN           NaN
# Murray Valley encephalitis virus              NaN           NaN
# Omsk hemorrhagic fever virus                  NaN           NaN
# Rio Bravo virus                               NaN           NaN
# Rocio virus                                   NaN           NaN
# St. Louis Encephalitis virus                  1.0           NaN
# Tembusu virus                                 NaN           2.0
# Tickborne encephalitis virus                  1.0           7.0
# Uganda S virus                                NaN           NaN
# Usutu virus                                   4.0           NaN
# Wesselsbron virus                             NaN           NaN
# West Nile virus                              17.0           5.0
# Yellow fever virus                            NaN           NaN
# Zika virus                                    NaN           NaN
#
# Order                             BUCEROTIFORMES  CAPRIMULGIFORMES  CARNIVORA  \
# Virus
# Apoi virus                                   NaN               NaN        NaN
# Bagaza virus                                 NaN               NaN        NaN
# Banzi virus                                  NaN               NaN        NaN
# Bouboui virus                                NaN               NaN        NaN
# Bussuquara virus                             NaN               NaN        NaN
# Cacipacore virus                             NaN               NaN        NaN
# Dakar bat virus                              NaN               NaN        NaN
# Dengue virus                                 NaN               NaN        NaN
# Entebbe bat virus                            NaN               NaN        NaN
# Iguape virus                                 NaN               NaN        NaN
# Ilheus virus                                 NaN               NaN        NaN
# Japanese encephalitis virus                  NaN               NaN        NaN
# Koutango virus                               NaN               NaN        NaN
# Kunjin virus                                 NaN               NaN        NaN
# Kyasanur forest virus                        NaN               NaN        NaN
# Louping-ill virus                            NaN               NaN        1.0
# Modoc virus                                  NaN               NaN        NaN
# Murray Valley encephalitis virus             NaN               NaN        NaN
# Omsk hemorrhagic fever virus                 NaN               NaN        NaN
# Rio Bravo virus                              NaN               NaN        NaN
# Rocio virus                                  NaN               NaN        NaN
# St. Louis Encephalitis virus                 NaN               NaN        1.0
# Tembusu virus                                NaN               NaN        NaN
# Tickborne encephalitis virus                 NaN               NaN        1.0
# Uganda S virus                               NaN               NaN        NaN
# Usutu virus                                  1.0               1.0        NaN
# Wesselsbron virus                            NaN               NaN        NaN
# West Nile virus                              1.0               NaN        4.0
# Yellow fever virus                           NaN               NaN        NaN
# Zika virus                                   NaN               NaN        NaN
#
# Order                             CATHARTIFORMES  CETARTIODACTYLA  \
# Virus
# Apoi virus                                   NaN              NaN
# Bagaza virus                                 NaN              NaN
# Banzi virus                                  NaN              NaN
# Bouboui virus                                NaN              NaN
# Bussuquara virus                             NaN              NaN
# Cacipacore virus                             NaN              NaN
# Dakar bat virus                              NaN              NaN
# Dengue virus                                 NaN              NaN
# Entebbe bat virus                            NaN              NaN
# Iguape virus                                 NaN              NaN
# Ilheus virus                                 NaN              NaN
# Japanese encephalitis virus                  NaN              5.0
# Koutango virus                               NaN              NaN
# Kunjin virus                                 NaN              1.0
# Kyasanur forest virus                        NaN              NaN
# Louping-ill virus                            NaN              7.0
# Modoc virus                                  NaN              NaN
# Murray Valley encephalitis virus             NaN              NaN
# Omsk hemorrhagic fever virus                 NaN              NaN
# Rio Bravo virus                              NaN              NaN
# Rocio virus                                  NaN              NaN
# St. Louis Encephalitis virus                 NaN              1.0
# Tembusu virus                                NaN              NaN
# Tickborne encephalitis virus                 NaN              8.0
# Uganda S virus                               NaN              NaN
# Usutu virus                                  NaN              1.0
# Wesselsbron virus                            NaN              1.0
# West Nile virus                              2.0              9.0
# Yellow fever virus                           NaN              NaN
# Zika virus                                   NaN              NaN
#
# Order                             CHARADRIIFORMES  CHIROPTERA  CICONIIFORMES  \
# Virus
# Apoi virus                                    NaN         NaN            NaN
# Bagaza virus                                  NaN         NaN            NaN
# Banzi virus                                   NaN         NaN            NaN
# Bouboui virus                                 NaN         NaN            NaN
# Bussuquara virus                              NaN         NaN            NaN
# Cacipacore virus                              NaN         NaN            NaN
# Dakar bat virus                               NaN         4.0            NaN
# Dengue virus                                  NaN        11.0            NaN
# Entebbe bat virus                             NaN         6.0            NaN
# Iguape virus                                  NaN         NaN            NaN
# Ilheus virus                                  NaN         NaN            NaN
# Japanese encephalitis virus                   NaN         9.0            NaN
# Koutango virus                                NaN         NaN            NaN
# Kunjin virus                                  NaN         NaN            NaN
# Kyasanur forest virus                         NaN         1.0            NaN
# Louping-ill virus                             NaN         NaN            NaN
# Modoc virus                                   NaN         NaN            NaN
# Murray Valley encephalitis virus              NaN         NaN            NaN
# Omsk hemorrhagic fever virus                  NaN         NaN            NaN
# Rio Bravo virus                               NaN         9.0            NaN
# Rocio virus                                   NaN         NaN            NaN
# St. Louis Encephalitis virus                  1.0         3.0            NaN
# Tembusu virus                                 NaN         NaN            NaN
# Tickborne encephalitis virus                  2.0         NaN            NaN
# Uganda S virus                                NaN         NaN            NaN
# Usutu virus                                   3.0         1.0            1.0
# Wesselsbron virus                             NaN         NaN            NaN
# West Nile virus                               9.0         4.0            1.0
# Yellow fever virus                            NaN         NaN            NaN
# Zika virus                                    NaN         NaN            NaN
#
# Order                             ...  PERISSODACTYLA  PHOENICOPTERIFORMES  \
# Virus                             ...
# Apoi virus                        ...             NaN                  NaN
# Bagaza virus                      ...             NaN                  NaN
# Banzi virus                       ...             NaN                  NaN
# Bouboui virus                     ...             NaN                  NaN
# Bussuquara virus                  ...             1.0                  NaN
# Cacipacore virus                  ...             1.0                  NaN
# Dakar bat virus                   ...             NaN                  NaN
# Dengue virus                      ...             1.0                  NaN
# Entebbe bat virus                 ...             NaN                  NaN
# Iguape virus                      ...             1.0                  NaN
# Ilheus virus                      ...             2.0                  NaN
# Japanese encephalitis virus       ...             2.0                  NaN
# Koutango virus                    ...             NaN                  NaN
# Kunjin virus                      ...             1.0                  NaN
# Kyasanur forest virus             ...             NaN                  NaN
# Louping-ill virus                 ...             1.0                  NaN
# Modoc virus                       ...             NaN                  NaN
# Murray Valley encephalitis virus  ...             2.0                  NaN
# Omsk hemorrhagic fever virus      ...             NaN                  NaN
# Rio Bravo virus                   ...             NaN                  NaN
# Rocio virus                       ...             1.0                  NaN
# St. Louis Encephalitis virus      ...             1.0                  NaN
# Tembusu virus                     ...             NaN                  NaN
# Tickborne encephalitis virus      ...             NaN                  NaN
# Uganda S virus                    ...             NaN                  NaN
# Usutu virus                       ...             2.0                  NaN
# Wesselsbron virus                 ...             1.0                  NaN
# West Nile virus                   ...             3.0                  1.0
# Yellow fever virus                ...             NaN                  NaN
# Zika virus                        ...             NaN                  NaN
#
# Order                             PICIFORMES  PILOSA  PRIMATES  \
# Virus
# Apoi virus                               NaN     NaN       NaN
# Bagaza virus                             NaN     NaN       NaN
# Banzi virus                              NaN     NaN       NaN
# Bouboui virus                            NaN     NaN       1.0
# Bussuquara virus                         NaN     NaN       1.0
# Cacipacore virus                         NaN     NaN       NaN
# Dakar bat virus                          NaN     NaN       NaN
# Dengue virus                             NaN     NaN       1.0
# Entebbe bat virus                        NaN     NaN       NaN
# Iguape virus                             NaN     NaN       NaN
# Ilheus virus                             NaN     NaN       1.0
# Japanese encephalitis virus              NaN     NaN       1.0
# Koutango virus                           NaN     NaN       NaN
# Kunjin virus                             NaN     NaN       NaN
# Kyasanur forest virus                    NaN     NaN       2.0
# Louping-ill virus                        NaN     NaN       NaN
# Modoc virus                              NaN     NaN       NaN
# Murray Valley encephalitis virus         NaN     NaN       NaN
# Omsk hemorrhagic fever virus             NaN     NaN       NaN
# Rio Bravo virus                          NaN     NaN       NaN
# Rocio virus                              NaN     NaN       NaN
# St. Louis Encephalitis virus             1.0     2.0       3.0
# Tembusu virus                            NaN     NaN       NaN
# Tickborne encephalitis virus             2.0     NaN       1.0
# Uganda S virus                           NaN     NaN       NaN
# Usutu virus                              2.0     NaN       NaN
# Wesselsbron virus                        NaN     NaN       NaN
# West Nile virus                          2.0     1.0       1.0
# Yellow fever virus                       NaN     NaN       9.0
# Zika virus                               NaN     NaN       7.0
#
# Order                             PSITTACIFORMES  RODENTIA  STRIGIFORMES  \
# Virus
# Apoi virus                                   NaN       4.0           NaN
# Bagaza virus                                 NaN       NaN           NaN
# Banzi virus                                  NaN       2.0           NaN
# Bouboui virus                                NaN       NaN           NaN
# Bussuquara virus                             NaN       1.0           NaN
# Cacipacore virus                             NaN       NaN           NaN
# Dakar bat virus                              NaN       NaN           NaN
# Dengue virus                                 NaN       7.0           NaN
# Entebbe bat virus                            NaN       NaN           NaN
# Iguape virus                                 NaN       NaN           NaN
# Ilheus virus                                 NaN       NaN           NaN
# Japanese encephalitis virus                  NaN       NaN           NaN
# Koutango virus                               NaN       NaN           NaN
# Kunjin virus                                 NaN       NaN           NaN
# Kyasanur forest virus                        NaN       3.0           NaN
# Louping-ill virus                            NaN       1.0           NaN
# Modoc virus                                  NaN       3.0           NaN
# Murray Valley encephalitis virus             NaN       NaN           NaN
# Omsk hemorrhagic fever virus                 NaN       3.0           NaN
# Rio Bravo virus                              NaN       NaN           NaN
# Rocio virus                                  NaN       NaN           NaN
# St. Louis Encephalitis virus                 NaN       4.0           1.0
# Tembusu virus                                NaN       NaN           NaN
# Tickborne encephalitis virus                 NaN      13.0           NaN
# Uganda S virus                               NaN       3.0           NaN
# Usutu virus                                  NaN       1.0           9.0
# Wesselsbron virus                            NaN       1.0           NaN
# West Nile virus                              3.0       9.0           4.0
# Yellow fever virus                           NaN       2.0           NaN
# Zika virus                                   NaN       NaN           NaN
#
# Order                             STRUTHIONIFORMES  SULIFORMES
# Virus
# Apoi virus                                     NaN         NaN
# Bagaza virus                                   NaN         NaN
# Banzi virus                                    NaN         NaN
# Bouboui virus                                  NaN         NaN
# Bussuquara virus                               NaN         NaN
# Cacipacore virus                               NaN         NaN
# Dakar bat virus                                NaN         NaN
# Dengue virus                                   NaN         NaN
# Entebbe bat virus                              NaN         NaN
# Iguape virus                                   NaN         NaN
# Ilheus virus                                   NaN         NaN
# Japanese encephalitis virus                    NaN         NaN
# Koutango virus                                 NaN         NaN
# Kunjin virus                                   NaN         NaN
# Kyasanur forest virus                          NaN         NaN
# Louping-ill virus                              NaN         NaN
# Modoc virus                                    NaN         NaN
# Murray Valley encephalitis virus               NaN         NaN
# Omsk hemorrhagic fever virus                   NaN         NaN
# Rio Bravo virus                                NaN         NaN
# Rocio virus                                    NaN         NaN
# St. Louis Encephalitis virus                   NaN         NaN
# Tembusu virus                                  NaN         NaN
# Tickborne encephalitis virus                   NaN         NaN
# Uganda S virus                                 NaN         NaN
# Usutu virus                                    NaN         NaN
# Wesselsbron virus                              NaN         NaN
# West Nile virus                                1.0         2.0
# Yellow fever virus                             NaN         NaN
# Zika virus                                     NaN         NaN
#
# [30 rows x 31 columns]
